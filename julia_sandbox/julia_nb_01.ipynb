# %% [markdown]
# # USANDO JULIA

# %% [markdown]
# Usar librerias

# %%
using Plots, StatsPlots

# %% [markdown]
# Código para graficar

# %%
begin
    f(t)=sin(t)
    g(t)=2*sin(t)
    plot(f,0,10,
    xlabel="Tiempo (s)",
    ylabel="Desplazamiento (m)")
    plot!(g,0,10)
end

# %% [markdown]
# \begin{equation}\label{eq:}
# k=\frac{24EI_{c}}{h^3}\frac{12\rho+1}{12\rho+4}
# \end{equation}

# %%
begin
   k(rho)=24*(12*rho+1)/(12*rho+4) 
end
# Out:
# k (generic function with 1 method)

# %%
begin
    plot(k,
    10^(-4),10^3,
    xaxis=:log,
    ylim=(0,24),
    
    )
end
